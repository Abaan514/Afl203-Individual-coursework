# %%
import pandas as pd

df = pd.read_csv('aapl.csv')

df.head()
# Out:
#          Date    Open    High     Low   Close    Volume  Adj Close
# 0  2008-10-14  116.26  116.40  103.14  104.08  70749800     104.08
# 1  2008-10-13  104.55  110.53  101.02  110.26  54967000     110.26
# 2  2008-10-10   85.70  100.00   85.00   96.80  79260700      96.80
# 3  2008-10-09   93.35   95.80   86.60   88.74  57763700      88.74
# 4  2008-10-08   85.91   96.33   85.68   89.79  78847900      89.79

# %%
import matplotlib.pyplot as plt

plt.plot(df['Date'], df['Close'])
plt.title('Apple Stock Price Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')

plt.show()

# %%
import matplotlib.pyplot as plt

df['Date'] = pd.to_datetime(df['Date'])

plt.figure(figsize=(12,6))

plt.plot(df['Date'], df['Close'])

plt.title('Apple Stock Price Over Time', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Close Price', fontsize=12)

plt.xticks(rotation=45)

plt.grid()

plt.show()

# %%
df.describe()
# Out:
#                                 Date         Open         High          Low  \
# count                           6081  6081.000000  6081.000000  6081.000000
# mean   1996-09-19 23:11:41.529353728    46.823511    47.681506    45.913595
# min              1984-09-07 00:00:00    12.880000    13.190000    12.720000
# 25%              1990-09-12 00:00:00    24.730000    25.010000    24.200000
# 50%              1996-09-16 00:00:00    38.250000    38.880000    37.460000
# 75%              2002-10-01 00:00:00    53.500000    54.550000    52.500000
# max              2008-10-14 00:00:00   200.590000   202.960000   197.800000
# std                              NaN    33.993517    34.578077    33.273106
#
#              Close        Volume    Adj Close
# count  6081.000000  6.081000e+03  6081.000000
# mean     46.798619  1.363986e+07    23.529794
# min      12.940000  8.880000e+04     1.650000
# 25%      24.690000  5.530000e+06     7.380000
# 50%      38.130000  8.976400e+06     9.910000
# 75%      53.610000  1.631920e+07    14.360000
# max     199.830000  2.650690e+08   199.830000
# std      33.947235  1.352107e+07    37.375601
